# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolinaBio2/Desafio-2-Biopy/blob/main/desafio_2_mod_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 16.8 MB/s eta 0:00:00
# ...

# %%
#Construir um arquivo de input com o nome do gene e as coordenadas dos genes presentes no arquivo lista_genes.txt; extrair esses dados do arquivo gbff do genoma de mycobacterium tuberculosis
#Usar os comandos da aula 2 mód 4 - inspecionando arquivos gbff; comandos de geração de arquivo input - aula 4 módulo 3

# %%
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
from Bio.SeqFeature import SeqFeature, FeatureLocation

# %%
#Abrindo o arquivo e lendo a ficha do genoma + anotações gerais
record = SeqIO.read("genomic_myc.tub.gbff", "genbank")
print(record.annotations)
print(list(record.annotations))
print(record.annotations['organism'])
print(record.dbxrefs)
# Out:
# {'molecule_type': 'DNA', 'topology': 'linear', 'data_file_division': 'CON', 'date': '14-DEC-2017', 'accessions': ['NC_000962'], 'sequence_version': 3, 'keywords': ['RefSeq', 'complete genome'], 'source': 'Mycobacterium tuberculosis H37Rv', 'organism': 'Mycobacterium tuberculosis H37Rv', 'taxonomy': ['Bacteria', 'Actinomycetota', 'Actinomycetes', 'Mycobacteriales', 'Mycobacteriaceae', 'Mycobacterium', 'Mycobacterium tuberculosis complex'], 'references': [Reference(title='TubercuList--10 years after', ...), Reference(title='Re-annotation of the genome sequence of Mycobacterium tuberculosis H37Rv', ...), Reference(title='Deciphering the biology of Mycobacterium tuberculosis from the complete genome sequence', ...), Reference(title='Direct Submission', ...), Reference(title='Direct Submission', ...)], 'comment': 'REVIEWED REFSEQ: This record has been curated by NCBI staff. The\nreference sequence is identical to AL123456.\nOn Feb 6, 2013 this sequence version replaced NC_000962.2.\nRefSe
# ...

# %%
print(record.letter_annotations)
print(record.features)
print(record.features[0])
print(record.features[0].type)
# Out:
# {}
# ...

# %%
#Iterando sobre a localização e acessando a sequência dos genes
print(record.features[0].location)
print(record.features[5].strand)
print(record.features[40].location.start) #localização no início
print(record.features[70].location.end) #localização do final
# Out:
# [0:4411532](+)
# 1
# 21636
# 36870

# %%
#Lendo a record
record = SeqIO.read("genomic_myc.tub.gbff", "genbank")

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features [2].location.end

#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)
# Out:
# ...

# %%
#Criando as coordenadas e extraindo a sequência de interesse
myseq = record.seq[start:end]
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
gene_id = record.features[1].qualifiers['gene']
print(gene_id, gene_interesse)

#Os comandos "gene_interesse e gene_id" serão usados para criar a pasta out
# Out:
# ['dnaA'] ...

# %%
#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_iteresse)

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse) # corrected variable name

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse)

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse) # corrected variable name

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse)

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse) # corrected variable name

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse)

#Recuperando o start e o end da feature de interesse
start = record.features[1].location.start
end = record.features[6].location.end
#Acessando a sequência do cromossomo todo
myseq = record.seq[start:end]
print(myseq)

#Criando as coordenadas e extraindo a sequência de interesse
coord = SeqFeature(FeatureLocation(start, end))
gene_interesse = coord.extract(myseq)
if 'gene' in record.features[1].qualifiers:
  gene_id = record.features[1].qualifiers['gene'] #definindo uma variável para armazenar o id do gene
  print(gene_id, gene_interesse)
else:
  print(gene_interesse) # corrected variable name

#Criando o arquivo out
out = open("output_coord.gbff", "w")
for seq_record in SeqIO.parse("genomic_myc.tub.gbff", "genbank"):
  if 'gene_id' in 'gene_interesse':
    print(gene_id, gene_interesse, file=out)
# Out:
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
# ...
# ['dnaA'] ...
